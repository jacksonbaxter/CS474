# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/porterjenkins/byu-cs474/blob/master/lab3_cross_entropy_convnets.ipynb)

# %% [markdown]
# # Deep Learning Part 3: Datasets, Data Loading, Cross Entropy, and Convolutional Networks
#
# ## Grading Standards:
# *  10%: Dataset/MNIST section
# *  10%: Correct implementation and use of cross entropy loss
# *  20%: Correct training/validation functions
# *  40%: Successful training and validation with MLP and convolution networks
# *  12%: Convolutional layer quiz
# *   8%: Comparison between MLP and convolution networks
# ___

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# Set your global variable `device`, using the `torch.device()` function. In order to use cuda remember to request a GPU from Runtime > Change Runtime.
#
# ***Important Note**: If you spend too much time or memory on the GPU in Google Colab then you will be timed out. This may not be a big deal with this lab, but it can become a big deal in later labs. It is recommended to set your `device` and Runtime to CPU first and once everything in the lab is working properly to set it to the GPU.*

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ---
#
# # Datasets and Data Loading

# %%
from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# We are going to make a PyTorch `Dataset`.
# There are three parts to creating a `Dataset`:
# 1. `__init__()`: This is where you get all relevant data for your dataset.
# 2. `__len__()`: You return how large your dataset is.
# 3. `__getitem__()`: You return an item from your dataset given an index.
#
# Implement the TODOs below.

# %%
class SineDataset(Dataset):
    def __init__(self):
        # TODO: The code is same from lab 2, so you can uncomment the code below.
        self.x = torch.rand((100,1))*8 - 4
        self.y = torch.sin(self.x) + torch.randn_like(self.x)*.1 # the second part of the sum adds noise to the function

    def __len__(self):
        # TODO: Return the len of your dataset.
        return len(self.x)
        pass

    def __getitem__(self, i):
        # TODO: i will be an index so return x_i and y_i
        return self.x[i], self.y[i]
        pass

# %% [markdown]
# Now create a `SineDataset` and print out the length of dataset, i.e. `len(dataset)`, and the item in your dataset at index 0, i.e. `dataset[0]`.

# %%
sine_dataset = SineDataset()
print(len(sine_dataset))
print(sine_dataset[0])
# Out:
# 100
# (tensor([1.6837]), tensor([0.9418]))

# %% [markdown]
# A `DataLoader` uses the `__len__` and `__getitem__` of a `Dataset` to sample indices in `[0, ..., len(dataset)-1]` and collect a batch of items from the `Dataset`.
# The `DataLoader` will then try to convert the sampled entries into tensors (if they are not already) and concatenate them together.
# Create a `DataLoader` object below; pass in your dataset and `batch_size=32` as arguments.

# %%
dataloader = DataLoader(sine_dataset, batch_size=32, shuffle=True)

# %% [markdown]
# Iterate through your dataloader with a for loop. Because `SineDataset.__getitem__()` returns two items, the for loop will return a tuple.
# Either unpack the entries in your tuple in the for loop:
# ```python
# for x, y in dataloader
# ```
# or after the loop:
# ```python
# for batch in dataloader:
#     x, y = batch
# ```
#
# Print out the shapes of `x` and `y` for each batch in the dataloader.

# %%
# Unpack x and y after fetching the batch
for batch in dataloader:
    x, y = batch
    print(f"x shape: {x.shape}, y shape: {y.shape}")
# Out:
# x shape: torch.Size([32, 1]), y shape: torch.Size([32, 1])
# x shape: torch.Size([32, 1]), y shape: torch.Size([32, 1])
# x shape: torch.Size([32, 1]), y shape: torch.Size([32, 1])
# x shape: torch.Size([4, 1]), y shape: torch.Size([4, 1])

# %% [markdown]
# You will notice that the shapes are `(B, Z_in)`, where `B` is batch size and `Z_in` is our input feature size, which is exactly what we want.
# Also note that the last batch has a batch size of 4; this is because the `DataLoader` samples **without replacement** and these are the last items in our `Dataset` that have not been sampled.
#
# Let's now create our real dataset.

# %% [markdown]
# ---
#
# # MNIST
#
# We are now going to look at the MNIST dataset, which is a dataset of handwritten numbers.
# Our objective will be to create a neural network that can predict the number given the image.
#
# First import `torchvision` below so we can retrieve the MNIST dataset.

# %%
import torchvision

# %% [markdown]
# You can use `torchvision.datasets.MNIST()` to download the MNIST dataset (which inherits the `Dataset` class).
# For arguments, specify `root="/tmp/"` to denote the location, `train=True` or `train=False` to get the training or test dataset, `download=True` to specify you want to download the dataset, and `transform=torchvision.transforms.ToTensor()` to convert the MNIST images from PIL images to PyTorch tensors.
# Create both a `train_dataset` and `val_dataset`.
#
# *Note: It is good practice to use a train, val, and test dataset, especially in the real world, but in this class we will mainly focus on train and val datasets to simplify things.*

# %%
from torchvision import datasets, transforms

# Define a transform to convert the images to PyTorch tensors
transform = transforms.ToTensor()

# Download and create the training dataset
train_dataset = datasets.MNIST(root="/tmp/", train=True, download=True, transform=transform)

# Download and create the validation dataset (using the test dataset as validation)
val_dataset = datasets.MNIST(root="/tmp/", train=False, download=True, transform=transform)

# %% [markdown]
# Print out the lengths of `train_dataset` and `val_dataset`.

# %%
# Print dataset sizes to confirm
print(f"Training dataset size: {len(train_dataset)}")
print(f"Validation dataset size: {len(val_dataset)}")
# Out:
# Training dataset size: 60000
# Validation dataset size: 10000

# %% [markdown]
# Grab element 0 from the `train_dataset`. As a heads up, like our `SineDataset`, `MNIST` returns an image `x` and a class/target `y`.

# %%
# Grab element 0 from train_dataset
x, y = train_dataset[0]

# %% [markdown]
# Use the `type()` function to see what type of object `x` and `y` are.

# %%
# Use type() to check the types of x and y
print(f"Type of x: {type(x)}")
print(f"Type of y: {type(y)}")
# Out:
# Type of x: <class 'torch.Tensor'>
# Type of y: <class 'int'>

# %% [markdown]
# Since x is a tensor, print out its `.dtype`, `.shape`

# %%
# Print the dtype and shape of x
print(f"x dtype: {x.dtype}")
print(f"x shape: {x.shape}")
# Out:
# x dtype: torch.float32
# x shape: torch.Size([1, 28, 28])

# %% [markdown]
# The shape of a tensor image is `(C, H, W)`, where `C` is channels, `H` is height, and `W` is width.
# In our case `x` has 1 channel and it is a 28x28 image.
# Because there is 1 channel, it is likely that the image is grayscale (which it is).
#
# Now visualize the image and display its class.
# Use the `plt.imshow()` function to visualize `x`; add the argument `cmap="gray"` to denote the image is grayscale.
# Use the `plt.title()` function to set the title of the `plt` image to the class `y`.
#
# *Note: `plt` expects grayscale images to only have to dimension, HxW, so `.squeeze()` the 0th dimension*

# %%
# Grab element 0 from train_dataset
x, y = train_dataset[0]

# Squeeze the 0th dimension (channel) so that the image is HxW
x_squeezed = x.squeeze(0)

# Visualize the image using plt.imshow and set cmap to "gray" for grayscale image
plt.imshow(x_squeezed, cmap="gray")

# Set the title of the image to the class label
plt.title(f"Class: {y}")

# Display the image
plt.show()

# %% [markdown]
# Print out the min and max values of `x` using `torch.min()` and `torch.max()`.

# %%
# Print the min and max values of the tensor x
print(f"Min value of x: {torch.min(x)}")
print(f"Max value of x: {torch.max(x)}")
# Out:
# Min value of x: 0.0
# Max value of x: 1.0

# %% [markdown]
# Our tensors are normalized between 0 and 1, which is good so we don't have to do any normalization.
# Now that we have a better understanding of our image data, let's examine the classes in the dataset.
#
# Create a `get_dataset_classes()` function which takes a dataset as input and count how many times each class appears.
# Return a dictionary where the keys are the classes and the values represent the number of times each class appears in the dataset.

# %%
def get_dataset_classes(dataset):
    # Initialize an empty dictionary to store class counts
    class_counts = {}

    # Loop through the dataset to access the class labels
    for _, label in dataset:
        # If the label is already in the dictionary, increment the count
        if label in class_counts:
            class_counts[label] += 1
        # If the label is not in the dictionary, add it with an initial count of 1
        else:
            class_counts[label] = 1

    # Return the dictionary with class counts
    return class_counts

# %% [markdown]
# Execute the code below to visualize the dataset classes.

# %%
train_classes = get_dataset_classes(train_dataset)
val_classes = get_dataset_classes(val_dataset)

def plot_classes(ax, classes, title):
    ax.bar(classes.keys(), classes.values())
    ax.set_title(title)
    ax.set_xticks(list(range(10)))

fig, axes = plt.subplots(1, 2, figsize=(8, 4))
plot_classes(axes[0], train_classes, "Train Dataset Classes")
plot_classes(axes[1], val_classes, "Val Dataset Classes")
plt.show()

# %% [markdown]
# There are 10 classes, which makes sense because there are 10 digits, 0-9.
# Furthermore, the classes are pretty evenly spread on both datasets, which means our baseline accuracy is roughly 10%.
#
# Now create two `DataLoader` objects called, `train_loader` and `val_loader`.
# The `train_loader` should have your `train_dataset` and the `val_loader` should have your `val_dataset`.
# Set the `batch_size` of both dataloaders equal to 32 and set `shuffle=True` for the `train_loader` so that the dataset is shuffled every time.
# To improve the speed at which you `DataLoader`s can load the data, set `num_workers=4` (for multiprocessing).

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=4)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# Now use `x, y = next(iter(train_loader))` to get a single batch of data from the `train_loader` and print out the shapes and dtypes of `x` and `y`

# %%
# Get a single batch of data from the train_loader
x, y = next(iter(train_loader))

# %% [markdown]
# The shape of `x` is `(B, C, H, W)`, where `B` is the batch size. **Always remember, in PyTorch, your data should have a batch dimension.**
# The shape of `y` is `(B,)` and it is a tensor of type `long`, which is what we want because we are doing classification, which means we want our target to be a class label.

# %% [markdown]
# ___
#
# ### MLP Network
#
# We are now going to make our network.
# Because we are doing image classification, the input to our network is a batch of images, `shape=(B, C, H, W)`, and the output of our network is a batch of probabilities, `shape=(B, K)`, where `K` represents the number classes in our dataset.
# In our case `K=10`.
#
# We will first try to solve this problem using a fully connected deep network (like your DeepNet from lab 2), sometimes called a Multi-Layer Perceptron (MLP).
# Implement an `MLP` below (don't forget to use `nn.Sequential`, `nn.Linear`, `nn.ReLU`).
# Because `nn.Linear` expects tensors of shape `(B, Z)`, where `Z` is the input feature size, we need to flatten our images. Use the `.view()` function to reshape `x.shape=(B, C, H, W)` into `x.shape=(B, Z)`, where `Z=C*H*W`.

# %%
class MLP(nn.Module):
    def __init__(self, in_features, out_features, hidden_size):
        super(MLP, self).__init__()

        # Define the fully connected layers and ReLU activations
        self.model = nn.Sequential(
            nn.Linear(in_features, hidden_size),  # Input to hidden layer
            nn.ReLU(),                            # Activation function
            nn.Linear(hidden_size, hidden_size),   # Hidden layer to hidden layer
            nn.ReLU(),                            # Activation function
            nn.Linear(hidden_size, out_features)   # Hidden layer to output layer (for 10 classes)
        )

    def forward(self, x):
        # Reshape input tensor from (B, C, H, W) to (B, C*H*W)
        B = x.size(0)  # Batch size
        x = x.view(B, -1)  # Flatten the input to (B, Z), where Z = C * H * W

        # Forward pass through the MLP
        return self.model(x)

# %% [markdown]
# Because we are doing classification, we need to use a different loss function that MSE; cross entropy loss is a good choice and is a common loss function for classification.

# %% [markdown]
# ---
#
# # Softmax and CrossEntropy
#
# The cross entropy (CE) function is $CE(p, q) = - \sum p(x) \log q(x)$, where $p$ and $q$ are probability functions ($p$ is the target probabilities and $q$ is the predicted probabilities) and in our case $x$ represents a class.
#
# $p$ represents the target distribution, the true class distribution, which means it is a one-hot vector $p_c$, where $c$ represents the index of the class:
# $$p_i = \begin{cases}
# 1, & \textrm{if } i = c \\
# 0, & \textrm{if } i \not = c \\
# \end{cases}$$
#
# Then $CE(p, q) = - \sum_i p_i \log q_i$ will become $CE(p, q) = - p_c \log q_c$, because $p_{i \not = c} = 0$, which is further reduced to $CE(p, q) = - \log q_c$, since $p_c = 1$. In other words, cross entropy loss for classification is the negative log of the predicted probability of the correct class.
#
# Therefore, $p$ is never passed into `F.cross_entropy_loss()`, instead you pass in $q$ you predicted distribution and $c$ the index of the correct class.
#
# Implement `prenormalized_cross_entropy_loss` below. $q$ is assumed to be a normalized probability distribution.
#
# *Note: Do **not** use a for loop. You can index into a tensor with array slicing (hint: You will need to use `torch.arange()` for the 0th dimension of `q`)*

# %%
def prenormalized_cross_entropy_loss(q, c):
    # Use torch.arange to get the batch indices
    batch_indices = torch.arange(q.size(0))

    # Get the predicted probability of the correct class for each sample using indexing
    correct_class_probs = q[batch_indices, c]

    # Compute the negative log of the predicted probabilities
    loss = -torch.log(correct_class_probs)

    # Return the average loss over the batch
    return loss.mean()

# %% [markdown]
# Validate your function below.

# %%
def test_prenormalized_cross_entropy_loss():
    q = torch.tensor([[.1, .5, .4],
                      [.2, .2, .6],
                      [.3, .3, .3]])
    c = torch.tensor([2, 0, 1])
    assert torch.allclose(prenormalized_cross_entropy_loss(q, c), torch.tensor(1.2432), atol=1e-4)

test_prenormalized_cross_entropy_loss()

# %% [markdown]
# This assumed that `q` was a probability distribution, but usually neural networks output logits $l$, which are unnormalized probabilities.
# One way we could normalize our logits $l$ into probabilities $q$ is to divide $l$ by the sum of logits $q_i = \frac{l_i}{\sum_j l_j}$, but that doesn't work if $l_i$ is negative.
# The softmax, which exponentiates the $logit$, $q_i = \frac{e^{l_i}}{\sum_j e^{l_j}}$, before dividing by the sum of exponentiated logits removes the issues of negativity (there are other good reasons for using softmax, such as numerical stability).
#
# However, applying `q = softmax(l)` to `prenormalized_cross_entropy_loss(q, c)` can still be numerically unstable.
# Luckily, we can simplify our function:
# $$\begin{align}
# CE(l, c) &= - \log \frac{e^{l_c}}{\sum_j e^{l_j}} \\
# &= - (\log e^{l_c} - \log \sum_j e^{l_j}) \\
# &= - (l_c - \log \sum_j e^{l_j}) \\
# &= - l_c + \log \sum_j e^{l_j}
# \end{align}$$
#
# While you could implement $\log \sum_j e^{l_j}$, you should use `torch.logsumexp()` which will exponentiate, sum, and then log your logits, but in a more numerically stable way.
# Implement `cross_entropy_loss()` below.
# You can validate it works by comparing it with the output of `F.cross_entropy()`.
#
# *Note: Do **not** use a for loop*

# %%
def cross_entropy_loss(l, c):
    # Get the batch size (B)
    B = l.size(0)

    # Compute l_c (the logits for the correct class)
    correct_class_logits = l[torch.arange(B), c]

    # Compute logsumexp for the logits across classes (dim=1 means sum over classes)
    logsumexp_logits = torch.logsumexp(l, dim=1)

    # Compute the cross-entropy loss: - (l_c - logsumexp_logits)
    loss = -(correct_class_logits - logsumexp_logits)

    # Return the average loss over the batch
    return loss.mean()

# %% [markdown]
# It is hard to tell how well a model is performing just from its cross entropy loss, so create a `get_accuracy()` function to measure accuracy.
# `get_accuracy()` takes in a `y_hat` and `y`, where `y_hat` contains the predicted logits (unnormalized probabilities) for some images `x` and `y` are the labels.
# You can get the predicted label from `y_hat`, by using the `torch.argmax()` function.
#
# *Note: Do **not** use a for loop.*

# %%
def get_accuracy(y_hat, y):
    # Get the predicted class by taking the argmax of the logits along the class dimension (dim=1)
    predicted_classes = torch.argmax(y_hat, dim=1)

    # Compare predicted classes with true labels and compute the accuracy
    accuracy = (predicted_classes == y).float().mean()

    return accuracy

# %% [markdown]
# ## Validation and Training

# %% [markdown]
# To see how well training is going, implement a `validation()` function to compute the average loss and accuracy over all instances in the `val_loader`.
# This function will look very similar to a basic training loop, but without any optimization, e.g. no `loss.backward()` or `optimizer.step()`.
# To speed up the process use `torch.no_grad()` to keep PyTorch from building the computation graph.
# You can use `torch.no_grad()` either as a decorator:
# ```python
# @torch.no_grad()
# def fn():
#     ...
# ```
# or as a context manager:
# ```python
# def fn():
#     with torch.no_grad():
#         ...
# ```
#
# *Remember you can use `.item()` on a tensor with one element to convert it into a float/int.*

# %%
def validation(net, val_loader):
    total_loss = 0.0
    total_accuracy = 0.0
    num_batches = 0

    net.eval()  # Set the model to evaluation mode
    with torch.no_grad():  # Disable gradient computation for validation
        for x, y in val_loader:
            # Move the input data and labels to the same device as the model
            x, y = x.to(device), y.to(device)

            # Forward pass
            y_hat = net(x)

            # Compute loss and accuracy
            loss = F.cross_entropy(y_hat, y)
            total_loss += loss.item()
            accuracy = get_accuracy(y_hat, y)
            total_accuracy += accuracy.item()
            num_batches += 1

    avg_loss = total_loss / num_batches
    avg_accuracy = total_accuracy / num_batches
    return avg_loss, avg_accuracy

# %% [markdown]
# Now implement the `train()` function.
# This will look similar to the `train()` you implemented in lab 2, but now you will also store training accuracies, and at every `log_val_interval` you will call `validation` and store the validation loss and accuracy.

# %%
def train(net, train_loader, val_loader, optimizer, n_optimization_steps, log_val_interval):
    # Lists to store training and validation metrics
    train_losses = []
    train_accuracies = []
    val_losses = []
    val_accuracies = []

    # Set the network to training mode
    net.train()

    # Initialize step counter
    step = 0

    # Loop over the training data for n_optimization_steps
    while step < n_optimization_steps:
        for x, y in train_loader:
            if step >= n_optimization_steps:
                break

            # Move the input data and labels to the same device as the model (GPU if available)
            x, y = x.to(device), y.to(device)

            # Zero the gradients before each step
            optimizer.zero_grad()

            # Forward pass: Compute the network output (logits)
            y_hat = net(x)

            # Compute the loss
            loss = F.cross_entropy(y_hat, y)

            # Backward pass: Compute gradients
            loss.backward()

            # Step the optimizer to update the model parameters
            optimizer.step()

            # Compute the accuracy for this batch
            accuracy = get_accuracy(y_hat, y)

            # Store the training loss and accuracy
            train_losses.append(loss.item())
            train_accuracies.append(accuracy.item())

            # Increment the optimization step counter
            step += 1

            # Every log_val_interval steps, evaluate on the validation dataset
            if step % log_val_interval == 0:
                val_loss, val_accuracy = validation(net, val_loader)
                val_losses.append(val_loss)
                val_accuracies.append(val_accuracy)
                print(f"Step {step}/{n_optimization_steps}, "
                      f"Train Loss: {loss.item():.4f}, Train Acc: {accuracy.item():.4f}, "
                      f"Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.4f}")

    # Return the stored training and validation losses and accuracies
    return train_losses, train_accuracies, val_losses, val_accuracies

# %% [markdown]
# Now train an `MLP` on `MNIST`. To speed up training use the `torch.optim.Adam` optimizer instead of `torch.optim.SGD`.
#
# *Note: Don't forget to put your network on `device`.*

# %%
import torch.optim as optim

# TODO: Set torch seed for reproducibility
torch.manual_seed(42)

# Initialize your MLP, called net
C, H, W = 1, 28, 28  # MNIST input dimensions
in_features = C * H * W  # Flattened input size
out_features = 10  # Number of classes for MNIST (digits 0-9)
hidden_size = 128  # Hidden layer size

net = MLP(in_features, out_features, hidden_size).to(device)

# Create an Adam optimizer with learning rate = 0.001
optimizer = optim.Adam(net.parameters(), lr=0.001)

# Train your MLP for 2000 steps and set log_val_interval = 50
n_optimization_steps = 2000
log_val_interval = 50

# Training loop (using train function defined earlier)
train_losses, train_accuracies, val_losses, val_accuracies = train(net, train_loader, val_loader, optimizer, n_optimization_steps, log_val_interval)

# At the end of the training, you can examine the training and validation metrics
print(f"Training complete! Final validation accuracy: {val_accuracies[-1] * 100:.2f}%")
# Out:
# Step 50/2000, Train Loss: 1.0292, Train Acc: 0.7188, Val Loss: 0.8227, Val Acc: 0.7641
# Step 100/2000, Train Loss: 0.6306, Train Acc: 0.7500, Val Loss: 0.5554, Val Acc: 0.8352
# Step 150/2000, Train Loss: 0.4126, Train Acc: 0.9688, Val Loss: 0.3940, Val Acc: 0.8869
# Step 200/2000, Train Loss: 0.5867, Train Acc: 0.7812, Val Loss: 0.3891, Val Acc: 0.8892
# Step 250/2000, Train Loss: 0.4269, Train Acc: 0.8750, Val Loss: 0.3395, Val Acc: 0.9033
# Step 300/2000, Train Loss: 0.2872, Train Acc: 0.8438, Val Loss: 0.3099, Val Acc: 0.9099
# Step 350/2000, Train Loss: 0.3584, Train Acc: 0.8438, Val Loss: 0.2846, Val Acc: 0.9186
# Step 400/2000, Train Loss: 0.5924, Train Acc: 0.8750, Val Loss: 0.2805, Val Acc: 0.9178
# Step 450/2000, Train Loss: 0.2273, Train Acc: 0.9375, Val Loss: 0.2627, Val Acc: 0.9232
# Step 500/2000, Train Loss: 0.3431, Train Acc: 0.8750, Val Loss: 0.2642, Val Acc: 0.9221
# Step 550/2000, Train Loss: 0.0870, Train Acc: 0.9688, Val Loss: 0.2419, Val Acc: 0.9274
# Step 600/2000, Train Loss: 0.1718, Train Acc: 0.9375, Val Loss: 0.2209, Val Acc: 0.9325
# Step 650/2000, Train Loss: 0.4596, Train Acc: 0.9062, Val Loss: 0.2251, Val Acc: 0.9332
# Step 700/2000, Train Loss: 0.3528, Train Acc: 0.8438, Val Loss: 0.2161, Val Acc: 0.9345
# Step 750/2000, Train Loss: 0.3587, Train Acc: 0.9062, Val Loss: 0.2061, Val Acc: 0.9360
# Step 800/2000, Train Loss: 0.0259, Train Acc: 1.0000, Val Loss: 0.2154, Val Acc: 0.9337
# Step 850/2000, Train Loss: 0.1736, Train Acc: 0.9375, Val Loss: 0.1908, Val Acc: 0.9425
# Step 900/2000, Train Loss: 0.2358, Train Acc: 0.9062, Val Loss: 0.1864, Val Acc: 0.9430
# Step 950/2000, Train Loss: 0.2688, Train Acc: 0.9375, Val Loss: 0.1769, Val Acc: 0.9466
# Step 1000/2000, Train Loss: 0.4475, Train Acc: 0.8125, Val Loss: 0.1967, Val Acc: 0.9403
# Step 1050/2000, Train Loss: 0.1286, Train Acc: 0.9688, Val Loss: 0.2087, Val Acc: 0.9363
# Step 1100/2000, Train Loss: 0.0269, Train Acc: 1.0000, Val Loss: 0.1954, Val Acc: 0.9394
# Step 1150/2000, Train Loss: 0.4110, Train Acc: 0.8750, Val Loss: 0.1680, Val Acc: 0.9508
# Step 1200/2000, Train Loss: 0.2327, Train Acc: 0.9375, Val Loss: 0.1624, Val Acc: 0.9519
# Step 1250/2000, Train Loss: 0.1953, Train Acc: 0.9688, Val Loss: 0.1590, Val Acc: 0.9521
# Step 1300/2000, Train Loss: 0.1086, Train Acc: 0.9688, Val Loss: 0.1453, Val Acc: 0.9570
# Step 1350/2000, Train Loss: 0.1850, Train Acc: 0.9062, Val Loss: 0.1862, Val Acc: 0.9434
# Step 1400/2000, Train Loss: 0.2380, Train Acc: 0.9062, Val Loss: 0.1519, Val Acc: 0.9531
# Step 1450/2000, Train Loss: 0.2136, Train Acc: 0.9375, Val Loss: 0.1416, Val Acc: 0.9581
# Step 1500/2000, Train Loss: 0.1026, Train Acc: 0.9688, Val Loss: 0.1468, Val Acc: 0.9547
# Step 1550/2000, Train Loss: 0.2419, Train Acc: 0.9062, Val Loss: 0.1509, Val Acc: 0.9562
# Step 1600/2000, Train Loss: 0.1516, Train Acc: 0.9375, Val Loss: 0.1464, Val Acc: 0.9557
# Step 1650/2000, Train Loss: 0.3372, Train Acc: 0.9688, Val Loss: 0.1361, Val Acc: 0.9591
# Step 1700/2000, Train Loss: 0.0865, Train Acc: 0.9688, Val Loss: 0.1353, Val Acc: 0.9588
# Step 1750/2000, Train Loss: 0.1990, Train Acc: 0.9688, Val Loss: 0.1424, Val Acc: 0.9550
# Step 1800/2000, Train Loss: 0.0982, Train Acc: 0.9688, Val Loss: 0.1282, Val Acc: 0.9617
# Step 1850/2000, Train Loss: 0.0360, Train Acc: 1.0000, Val Loss: 0.1222, Val Acc: 0.9622
# Step 1900/2000, Train Loss: 0.1516, Train Acc: 0.9375, Val Loss: 0.1375, Val Acc: 0.9579
# Step 1950/2000, Train Loss: 0.0273, Train Acc: 1.0000, Val Loss: 0.1267, Val Acc: 0.9600
# Step 2000/2000, Train Loss: 0.4387, Train Acc: 0.9062, Val Loss: 0.1315, Val Acc: 0.9593
# Training complete! Final validation accuracy: 95.93%

# %% [markdown]
# Now plot your training and validation loss on the same plot and plot your training and validation accuracies on the same plot.
# Properly set your x- and y-axis labels and create a legend to make your plot legible.
#
# *Note: that you can specify the x-values for each point by calling `plt.plot(x, y)` instead of `plt.plot(y)`. Since you store validation every 50 steps, you'll need to use `torch.arange` to get the proper x-values to align the validation results to the training results.*

# %%
# Get the x-values for validation metrics (log_val_interval steps)
val_steps = torch.arange(log_val_interval, n_optimization_steps + 1, log_val_interval)

# Plot training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(torch.arange(len(train_losses)), train_losses, label='Train Loss')
plt.plot(val_steps, val_losses, label='Validation Loss', marker='o')
plt.xlabel('Training Steps')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# Plot training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(torch.arange(len(train_accuracies)), train_accuracies, label='Train Accuracy')
plt.plot(val_steps, val_accuracies, label='Validation Accuracy', marker='o')
plt.xlabel('Training Steps')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ___
#
# # Convolution Networks
#
# Now we will create a convolution network.
# When we were dealing with an `MLP` we used fully-connected `nn.Linear` layers.
# In a convolution network we use `nn.Conv2d` layers.
# `nn.Linear` maps tensors of shape `(B, F_in) -> (B, F_out)`.
# `nn.Conv2d` maps tensors of shape `(B, C_in, H_in, W_in) -> (B, C_out, H_out, W_out)`, where `C_in` represents our input channels and `C_out` represents our output channels.
# You decide what `C_out` should be when you initialize.
# The mapping that
#
# If we had a batch of `img` tensors with shape `(B, 3, 8, 8)` and we wanted it to become `(B, 6, 4, 4)` we could create a convolution layer:
# ```python
# conv_layer = nn.Conv2d(in_channels=3,  # Our 'C_in' which is 3
#                        out_channels=6, # Our desired 'C_out'
#                        kernel_size=2,  # One way to make an 8x8 image become a 2x2 image is to have the kernel be 2x2,
#                        padding=0,      #    with zero padding,
#                        stride=2,       #    and a stride of 2.
#                       )
# ```
# Validate this is true below by creating `conv_prac()` function, which creates a random tensor with shape `(B, 3, 8, 8)`, passes it through `conv_layer`, and prints out the resulting shape.
#
# *Note: `kernel_size`, `padding`, and `stride` can all be tuples in case you want different (height, width) parameters, e.g. `kernel=(kernel_height, kernel_width)`.*

# %%
def conv_prac():
    # Define batch size and input shape (B, 3, 8, 8)
    B = 1
    input_tensor = torch.randn(B, 3, 8, 8)

    # Create a Conv2D layer
    conv_layer = nn.Conv2d(
        in_channels=3,   # C_in = 3 input channels
        out_channels=6,  # C_out = 6 output channels
        kernel_size=2,   # Kernel size of 2x2
        padding=0,       # No padding
        stride=2         # Stride of 2
    )

    # Pass the input tensor through the convolution layer
    output_tensor = conv_layer(input_tensor)

    # Print the shape of the output tensor
    print(f"Input shape: {input_tensor.shape}")
    print(f"Output shape: {output_tensor.shape}")

# Call the function to test
conv_prac()
# Out:
# Input shape: torch.Size([1, 3, 8, 8])
# Output shape: torch.Size([1, 6, 4, 4])

# %% [markdown]
# ___
#
# ### Quiz
# Test your knowledge of how convolution layers affect the shape of outputs by answering the following quiz questions.
#
#
# *Using a Kernel size of 3×3 what should the settings of your 2d convolution be that results in the following mappings (first answer given to you)*
#
# * (c=3, h=10, w=10) ⇒ (c=10, h=8, w=8) : **(out_channels=10, kernel_size=(3, 3), padding=(0, 0))**
# * (c=3, h=10, w=10) ⇒ (c=22, h=10, w=10) : **(out_channels=22, kernel_size=(3, 3), padding=(1, 1))**
# * (c=3, h=10, w=10) ⇒ (c=65, h=12, w=12) : **(out_channels=65, kernel_size=(3, 3), padding=(2, 2))**
# * (c=3, h=10, w=10) ⇒ (c=7, h=20, w=20) : **(out_channels=7, kernel_size=(3, 3), padding=(6, 6))**
#
# *Using a Kernel size of 5×5:*
#
# * (c=3, h=10, w=10) ⇒ (c=10, h=8, w=8) : (out_channels=10, kernel_size=(5, 5), padding=(1, 1))
# * (c=3, h=10, w=10) ⇒ (c=100, h=10, w=10) : **(out_channels=100, kernel_size=(5, 5), padding=(2, 2))**
# * (c=3, h=10, w=10) ⇒ (c=23, h=12, w=12) : **(out_channels=23, kernel_size=(5, 5), padding=(3, 3))**
# * (c=3, h=10, w=10) ⇒ (c=5, h=24, w=24) : **(out_channels=5, kernel_size=(5, 5), padding=(9, 9))**
#
# *Using Kernel size of 5×3:*
#
# * (c=3, h=10, w=10) ⇒ (c=10, h=8, w=8) : **(out_channels=10, kernel_size=(5, 3), padding=(1, 0))**
# * (c=3, h=10, w=10) ⇒ (c=100, h=10, w=10) : **(out_channels=100, kernel_size=(5, 3), padding=(2, 1))**
# * (c=3, h=10, w=10) ⇒ (c=23, h=12, w=12) : **(out_channels=23, kernel_size=(5, 3), padding=(3, 2))**
# * (c=3, h=10, w=10) ⇒ (c=5, h=24, w=24) : **(out_channels=5, kernel_size=(5, 3), padding=(9, 6))**
#
# *Determine the kernel that requires the smallest padding size to make the following mappings possible:*
#
# * (c=3, h=10, w=10) ⇒ (c=10, h=9, w=7) : **kernel_size=(2, 4), stride=(1, 1), padding=(0, 0)**
# * (c=3, h=10, w=10) ⇒ (c=22, h=10, w=10) : **kernel_size=(1, 1), padding=(0, 0)**

# %% [markdown]
# ## ConvNet
#
# Now create a convolution network `ConvNet` that inherits `nn.Module`.
# The network should have 3 convolution layers (each layer should have 16 output channels):
# 1. Conv Layer 1 should have a 6x6 kernel, no padding, and a stride of 2.
# 2. Conv Layer 2 should have a 4x4 kernel, no padding, and a stride of 2.
# 3. Conv Layer 3 should have a 3x3 kernel, no padding, and a stride of 1.
#
# The output of these layers should be a 3x3 image with 16 channels.
# You should flatten the image (you can use `.view()`, `torch.flatten()`, or `nn.Flatten()`) and then pass it through 2 linear layers:
# 1. Linear Layer 1 should take the flattened image and map it to a vector with 16 features.
# 2. Linear Layer 2 should map its vector to logits.
#
# Do not forget to add nonlinearities between the layers (do not add them to the last layer).

# %%
import torch
import torch.nn as nn

class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()

        # Update the input channels to 1 for grayscale images (MNIST)
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=16, kernel_size=6, stride=2, padding=0)  # Conv layer 1
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=4, stride=2, padding=0)  # Conv layer 2
        self.conv3 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, stride=1, padding=0)  # Conv layer 3

        # Define the fully connected (linear) layers
        self.fc1 = nn.Linear(16 * 3 * 3, 16)  # Linear layer 1, input size 16*3*3 (flattened)
        self.fc2 = nn.Linear(16, 10)  # Linear layer 2, output size 10 (for 10 classes, e.g., digits 0-9)

        # Non-linearity (ReLU) for the layers (except the final one)
        self.relu = nn.ReLU()

    def forward(self, x):
        # Pass through the convolutional layers with ReLU activation
        x = self.relu(self.conv1(x))  # Output size (B, 16, 3, 3)
        x = self.relu(self.conv2(x))  # Output size (B, 16, 3, 3)
        x = self.relu(self.conv3(x))  # Output size (B, 16, 3, 3)

        # Flatten the output from the conv layers
        x = torch.flatten(x, 1)  # Flatten the feature map to shape (B, 16*3*3)

        # Pass through the fully connected layers
        x = self.relu(self.fc1(x))  # First linear layer
        logits = self.fc2(x)  # Output logits (for classification)

        return logits

# %% [markdown]
# Train you convolution network below.

# %%
# TODO: Set seed for reproducibility
torch.manual_seed(42)

# TODO: Initalize your ConvNet, called 'conv_net'
conv_net = ConvNet().to(device)

# TODO: Create an Adam optimizer (lr=.001 works well)
optimizer = optim.Adam(conv_net.parameters(), lr=0.001)

# TODO: Train your ConvNet for 2000 steps and set log_val_interval=50
n_optimization_steps = 2000
log_val_interval = 50
# Training loop (using train function defined earlier)
train_losses, train_accuracies, val_losses, val_accuracies = train(net, train_loader, val_loader, optimizer, n_optimization_steps, log_val_interval)

# At the end of the training, you can examine the training and validation metrics
print(f"Training complete! Final validation accuracy: {val_accuracies[-1] * 100:.2f}%")
# Out:
# Step 50/2000, Train Loss: 0.1642, Train Acc: 0.9375, Val Loss: 0.1315, Val Acc: 0.9593
# Step 100/2000, Train Loss: 0.1996, Train Acc: 0.8750, Val Loss: 0.1315, Val Acc: 0.9593
# Step 150/2000, Train Loss: 0.0851, Train Acc: 0.9688, Val Loss: 0.1315, Val Acc: 0.9593
# Step 200/2000, Train Loss: 0.0379, Train Acc: 1.0000, Val Loss: 0.1315, Val Acc: 0.9593
# Step 250/2000, Train Loss: 0.0720, Train Acc: 0.9688, Val Loss: 0.1315, Val Acc: 0.9593
# Step 300/2000, Train Loss: 0.0676, Train Acc: 1.0000, Val Loss: 0.1315, Val Acc: 0.9593
# Step 350/2000, Train Loss: 0.1631, Train Acc: 0.9375, Val Loss: 0.1315, Val Acc: 0.9593
# Step 400/2000, Train Loss: 0.1448, Train Acc: 0.9688, Val Loss: 0.1315, Val Acc: 0.9593
# Step 450/2000, Train Loss: 0.0339, Train Acc: 1.0000, Val Loss: 0.1315, Val Acc: 0.9593
# Step 500/2000, Train Loss: 0.0300, Train Acc: 1.0000, Val Loss: 0.1315, Val Acc: 0.9593
# Step 550/2000, Train Loss: 0.0411, Train Acc: 1.0000, Val Loss: 0.1315, Val Acc: 0.9593
# Step 600/2000, Train Loss: 0.0117, Train Acc: 1.0000, Val Loss: 0.1315, Val Acc: 0.9593
# Step 650/2000, Train Loss: 0.0639, Train Acc: 0.9688, Val Loss: 0.1315, Val Acc: 0.9593
# Step 700/2000, Train Loss: 0.0798, Train Acc: 0.9688, Val Loss: 0.1315, Val Acc: 0.9593
# Step 750/2000, Train Loss: 0.0369, Train Acc: 1.0000, Val Loss: 0.1315, Val Acc: 0.9593
# Step 800/2000, Train Loss: 0.0809, Train Acc: 0.9688, Val Loss: 0.1315, Val Acc: 0.9593
# Step 850/2000, Train Loss: 0.0322, Train Acc: 1.0000, Val Loss: 0.1315, Val Acc: 0.9593
# Step 900/2000, Train Loss: 0.0473, Train Acc: 1.0000, Val Loss: 0.1315, Val Acc: 0.9593
# Step 950/2000, Train Loss: 0.1631, Train Acc: 0.9688, Val Loss: 0.1315, Val Acc: 0.9593
# Step 1000/2000, Train Loss: 0.0268, Train Acc: 1.0000, Val Loss: 0.1315, Val Acc: 0.9593
# Step 1050/2000, Train Loss: 0.0778, Train Acc: 0.9375, Val Loss: 0.1315, Val Acc: 0.9593
# Step 1100/2000, Train Loss: 0.4983, Train Acc: 0.9688, Val Loss: 0.1315, Val Acc: 0.9593
# Step 1150/2000, Train Loss: 0.0379, Train Acc: 0.9688, Val Loss: 0.1315, Val Acc: 0.9593
# Step 1200/2000, Train Loss: 0.1693, Train Acc: 0.9375, Val Loss: 0.1315, Val Acc: 0.9593
# Step 1250/2000, Train Loss: 0.1193, Train Acc: 0.9688, Val Loss: 0.1315, Val Acc: 0.9593
# Step 1300/2000, Train Loss: 0.0354, Train Acc: 1.0000, Val Loss: 0.1315, Val Acc: 0.9593
# Step 1350/2000, Train Loss: 0.0221, Train Acc: 1.0000, Val Loss: 0.1315, Val Acc: 0.9593
# Step 1400/2000, Train Loss: 0.0225, Train Acc: 1.0000, Val Loss: 0.1315, Val Acc: 0.9593
# Step 1450/2000, Train Loss: 0.2149, Train Acc: 0.9375, Val Loss: 0.1315, Val Acc: 0.9593
# Step 1500/2000, Train Loss: 0.0478, Train Acc: 1.0000, Val Loss: 0.1315, Val Acc: 0.9593
# Step 1550/2000, Train Loss: 0.0301, Train Acc: 1.0000, Val Loss: 0.1315, Val Acc: 0.9593
# Step 1600/2000, Train Loss: 0.0289, Train Acc: 1.0000, Val Loss: 0.1315, Val Acc: 0.9593
# Step 1650/2000, Train Loss: 0.1369, Train Acc: 0.9375, Val Loss: 0.1315, Val Acc: 0.9593
# Step 1700/2000, Train Loss: 0.1369, Train Acc: 0.9688, Val Loss: 0.1315, Val Acc: 0.9593
# Step 1750/2000, Train Loss: 0.1100, Train Acc: 0.9688, Val Loss: 0.1315, Val Acc: 0.9593
# Step 1800/2000, Train Loss: 0.0441, Train Acc: 1.0000, Val Loss: 0.1315, Val Acc: 0.9593
# Step 1850/2000, Train Loss: 0.1919, Train Acc: 0.9375, Val Loss: 0.1315, Val Acc: 0.9593
# Step 1900/2000, Train Loss: 0.0823, Train Acc: 1.0000, Val Loss: 0.1315, Val Acc: 0.9593
# Step 1950/2000, Train Loss: 0.0288, Train Acc: 1.0000, Val Loss: 0.1315, Val Acc: 0.9593
# Step 2000/2000, Train Loss: 0.1335, Train Acc: 0.9375, Val Loss: 0.1315, Val Acc: 0.9593
# Training complete! Final validation accuracy: 95.93%

# %% [markdown]
# Now plot your training and validation loss on the same plot and plot your training and validation accuracies on the same plot.

# %%
# Generate steps for validation metrics based on log_val_interval
log_val_interval = 50
val_steps = torch.arange(log_val_interval, log_val_interval * len(val_losses) + 1, log_val_interval)

# Plot training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(torch.arange(len(train_losses)), train_losses, label='Train Loss')
plt.plot(val_steps, val_losses, label='Validation Loss', marker='o')
plt.xlabel('Training Steps')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# Plot training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(torch.arange(len(train_accuracies)), train_accuracies, label='Train Accuracy')
plt.plot(val_steps, val_accuracies, label='Validation Accuracy', marker='o')
plt.xlabel('Training Steps')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Create a function that outputs the number of parameters in a network.
# Remember you can call `.parameters()` to recursively retrieve the `Parameter`s in a `Module`.
# You could then use `.shape` to figure out the number of parameters in a `Parameter` or you could flatten the parameter and get its length.

# %%
def get_n_net_params(net):
    total_params = sum(p.numel() for p in net.parameters())
    return total_params

# %% [markdown]
# Print the number of parameters and the accuracy of your trained `MLP` and `ConvNet` networks and then write down below:
# - Which one is more accurate?
# - Which one is smaller?
#
# *Note: You can use `validation()` to get the accuracy of your network.*

# %%
# Move the MLP model to the correct device (same as ConvNet)
net.to(device)
conv_net = ConvNet().to(device)  # Reinitialize with correct input channels

# Compute the number of parameters for each model
mlp_params = get_n_net_params(net)
conv_net_params = get_n_net_params(conv_net)

# Get validation accuracy for both models
mlp_val_loss, mlp_val_accuracy = validation(net, val_loader)
conv_net_val_loss, conv_net_val_accuracy = validation(conv_net, val_loader)

# Output results
print(f"MLP - Number of parameters: {mlp_params}, Validation Accuracy: {mlp_val_accuracy * 100:.2f}%")
print(f"ConvNet - Number of parameters: {conv_net_params}, Validation Accuracy: {conv_net_val_accuracy * 100:.2f}%")
# Out:
# MLP - Number of parameters: 118282, Validation Accuracy: 95.93%
# ConvNet - Number of parameters: 9514, Validation Accuracy: 10.08%
